# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.array([[1,2], [3,4]])
print(A)
# Out:
# [[1 2]
#  [3 4]]

# %%
A.shape
# Out:
# (2, 2)

# %%
A.dtype
# Out:
# dtype('int64')

# %%
x = np.arange(0, 6 ,0.1)
y = np.sin(x)

plt.plot(x,y)
plt.show()
